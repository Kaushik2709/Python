# %%
import pandas as pd

df = pd.read_parquet("results.parquet")
df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# # "openpyxl" This used to open excel files
# # "pandas" This is used to read and manipulate data in excel files
# # "matplotlib" This is used to create visualizations and charts from the data in excel files
# # "numpy" This is used for numerical operations and data manipulation in excel files
# # "pyarrow" This is used to see Parquet files which are a columnar storage file format used for efficient data processing and storage.

# %%
df.loc[df["year"] == 2022, "type"]
# Out:
# 173195    Winter
# 173196    Winter
# 213793    Winter
# 213794    Winter
# 215139    Winter
#            ...
# 308403    Winter
# 308404    Winter
# 308405    Winter
# 308406    Winter
# 308407    Winter
# Name: type, Length: 4744, dtype: str

# %%
df.iloc[[0,1,2]]
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis  Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc            team  place   tied medal
# 0           1  FRA             NaN   17.0   True   NaN
# 1           1  FRA  Jean Montariol    NaN  False   NaN
# 2           1  FRA             NaN   32.0   True   NaN

# %%
df.sort_values(by="year", ascending=False)
# Out:
#           year    type                     discipline  \
# 308361  2022.0  Winter        Ice Hockey (Ice Hockey)
# 308405  2022.0  Winter         Alpine Skiing (Skiing)
# 308386  2022.0  Winter  Cross Country Skiing (Skiing)
# 308407  2022.0  Winter                            NaN
# 308404  2022.0  Winter         Alpine Skiing (Skiing)
# ...        ...     ...                            ...
# 203177     NaN     NaN                        Fencing
# 203178     NaN     NaN                        Fencing
# 217586     NaN     NaN            Football (Football)
# 217587     NaN     NaN            Football (Football)
# 271490     NaN     NaN              Diving (Aquatics)
#
#                                          event                    as  \
# 308361               Ice Hockey, Men (Olympic)          Dario Simion
# 308405                   Team, Mixed (Olympic)         Hilma Lövblom
# 308386  30 kilometres Skiathlon, Men (Olympic)          Ján Koristek
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  str
#  2   discipline  308407 non-null  str
#  3   event       308408 non-null  str
#  4   as          308408 non-null  str
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  str
#  7   team        121714 non-null  str
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   str
# dtypes: bool(1), float64(2), int64(1), str(7)
# memory usage: 46.0 MB

# %%
df.loc[df["medal"] == "Gold", ["event",'team']]
# Out:
#                                 event             team
# 40        Singles, Men (Intercalated)              NaN
# 41      Doubles, Mixed (Intercalated)    Marie Decugis
# 42        Doubles, Men (Intercalated)   Maurice Germot
# 48           Doubles, Mixed (Olympic)  Suzanne Lenglen
# 80        Doubles, Men (Intercalated)      Max Decugis
# ...                               ...              ...
# 308139          Team, Mixed (Olympic)              ROC
# 308141          Team, Mixed (Olympic)              ROC
# 308290    Giant Slalom, Men (Olympic)              NaN
# 308326       Relay, Mixed Youth (YOG)         Europe 1
# 308340       Ski Cross, Men (Olympic)              NaN
#
# [14783 rows x 2 columns]
